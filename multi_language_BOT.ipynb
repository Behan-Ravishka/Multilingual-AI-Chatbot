# %%
# !pip install streamlit ollama
# Out:
# Requirement already satisfied: streamlit in .\kdu_env\Lib\site-packages (1.59.0)
# Requirement already satisfied: ollama in .\kdu_env\Lib\site-packages (0.6.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\kdu_env\Lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\kdu_env\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\kdu_env\Lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in .\kdu_env\Lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\kdu_env\Lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in .\kdu_env\Lib\site-packages (from streamlit) (2.5.1)
# Requirement already satisfied: packaging>=20 in .\kdu_env\Lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in .\kdu_env\Lib\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\kdu_env\Lib\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\kdu_env\Lib\site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=3.20 in .\kdu_env\Lib\site-packages (from streamlit) (7.35.1)
# Requirement already satisfied: pyarrow>=7.0 in .\kdu_env\Lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in .\kdu_env\Lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\kdu_env\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in .\kdu_env\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\kdu_env\Lib\site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette>=0.40.0 in .\kdu_env\Lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in .\kdu_env\Lib\site-packages (from streamlit) (0.50.2)
# Requirement already satisfied: httptools>=0.6.3 in .\kdu_env\Lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in .\kdu_env\Lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: python-multipart>=0.0.10 in .\kdu_env\Lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in .\kdu_env\Lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in .\kdu_env\Lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\kdu_env\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\kdu_env\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\kdu_env\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in .\kdu_env\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.23.0)
# Requirement already satisfied: colorama in .\kdu_env\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\kdu_env\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\kdu_env\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\kdu_env\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\kdu_env\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\kdu_env\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.8)
# Requirement already satisfied: idna<4,>=2.5 in .\kdu_env\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\kdu_env\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\kdu_env\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: httpx>=0.27 in .\kdu_env\Lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in .\kdu_env\Lib\site-packages (from ollama) (2.13.4)
# Requirement already satisfied: httpcore==1.* in .\kdu_env\Lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\kdu_env\Lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\kdu_env\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\kdu_env\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\kdu_env\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\kdu_env\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\kdu_env\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: annotated-types>=0.6.0 in .\kdu_env\Lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\kdu_env\Lib\site-packages (from pydantic>=2.9->ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\kdu_env\Lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: six>=1.5 in .\kdu_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)

# %%
import streamlit as st
import ollama

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
SYSTEM_PROMPT = {
    "role": "system",
    "content": """
You are a highly accurate multilingual AI assistant for Sri Lanka.

Rules:
1. Detect the user's language automatically.
2. If the user writes in Sinhala, reply only in Sinhala.
3. If the user writes in Tamil, reply only in Tamil.
4. If the user writes in English, reply only in English.
5. Never mix languages unless the user mixes them.
6. If unsure, clearly say you do not know.
7. Never hallucinate or invent facts.
8. Keep responses short, accurate, and helpful.

Examples:

User: කොහොමද?
Assistant: මට හොඳයි. ඔබට කොහොමද?

User: உங்கள் பெயர் என்ன?
Assistant: நான் ஒரு AI உதவியாளர்.

User: What is the capital of Sri Lanka?
Assistant: Sri Jayawardenepura Kotte is the administrative capital of Sri Lanka.
"""
}

print(SYSTEM_PROMPT)
# Out:
# {'role': 'system', 'content': "\nYou are a highly accurate multilingual AI assistant for Sri Lanka.\n\nRules:\n1. Detect the user's language automatically.\n2. If the user writes in Sinhala, reply only in Sinhala.\n3. If the user writes in Tamil, reply only in Tamil.\n4. If the user writes in English, reply only in English.\n5. Never mix languages unless the user mixes them.\n6. If unsure, clearly say you do not know.\n7. Never hallucinate or invent facts.\n8. Keep responses short, accurate, and helpful.\n\nExamples:\n\nUser: කොහොමද?\nAssistant: මට හොඳයි. ඔබට කොහොමද?\n\nUser: உங்கள் பெயர் என்ன?\nAssistant: நான் ஒரு AI உதவியாளர்.\n\nUser: What is the capital of Sri Lanka?\nAssistant: Sri Jayawardenepura Kotte is the administrative capital of Sri Lanka.\n"}

# %%
messages = []

messages.append(SYSTEM_PROMPT)

messages.append({
    "role": "user",
    "content": "Hello"
})

print(messages)
# Out:
# [{'role': 'system', 'content': "\nYou are a highly accurate multilingual AI assistant for Sri Lanka.\n\nRules:\n1. Detect the user's language automatically.\n2. If the user writes in Sinhala, reply only in Sinhala.\n3. If the user writes in Tamil, reply only in Tamil.\n4. If the user writes in English, reply only in English.\n5. Never mix languages unless the user mixes them.\n6. If unsure, clearly say you do not know.\n7. Never hallucinate or invent facts.\n8. Keep responses short, accurate, and helpful.\n\nExamples:\n\nUser: කොහොමද?\nAssistant: මට හොඳයි. ඔබට කොහොමද?\n\nUser: உங்கள் பெயர் என்ன?\nAssistant: நான் ஒரு AI உதவியாளர்.\n\nUser: What is the capital of Sri Lanka?\nAssistant: Sri Jayawardenepura Kotte is the administrative capital of Sri Lanka.\n"}, {'role': 'user', 'content': 'Hello'}]

# %%
response = ollama.chat(
    model="gemma3:12b",
    messages=[
        SYSTEM_PROMPT,
        {
            "role": "user",
            "content": "කොහොමද?"
        }
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 response = ollama.chat(
#       2     model="gemma3:12b",
#       3     messages=[
#       4         SYSTEM_PROMPT,
#       5         {
#       6             "role": "user",
#       7             "content": "කොහොමද?"
#       8         }
#       9     ]
#      10 )
#      12 print(response["message"]["content"])
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'gemma3:12b' not found (status code: 404)

# %%
response = ollama.chat(
    model="gemma3:12b",
    messages=[
        SYSTEM_PROMPT,
        {
            "role": "user",
            "content": "உங்கள் பெயர் என்ன?"
        }
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response = ollama.chat(
#       2     model="gemma3:12b",
#       3     messages=[
#       4         SYSTEM_PROMPT,
#       5         {
#       6             "role": "user",
#       7             "content": "உங்கள் பெயர் என்ன?"
#       8         }
#       9     ]
#      10 )
#      12 print(response["message"]["content"])
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'gemma3:12b' not found (status code: 404)

# %%
response = ollama.chat(
    model="gemma3:12b",
    messages=[
        SYSTEM_PROMPT,
        {
            "role": "user",
            "content": "Tell me about Sri Lanka"
        }
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response = ollama.chat(
#       2     model="gemma3:12b",
#       3     messages=[
#       4         SYSTEM_PROMPT,
#       5         {
#       6             "role": "user",
#       7             "content": "Tell me about Sri Lanka"
#       8         }
#       9     ]
#      10 )
#      12 print(response["message"]["content"])
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\envs\llm_env\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'gemma3:12b' not found (status code: 404)

# %%
css = """
<style>

.stApp {
    background-color: #f0f2f5;
}

.user-bubble {
    background-color: #dcf8c6;
    color: black;
    padding: 10px;
    border-radius: 15px;
    margin-bottom: 10px;
}

.bot-bubble {
    background-color: white;
    color: black;
    padding: 10px;
    border-radius: 15px;
    margin-bottom: 10px;
}

</style>
"""

print(css)
# Out:
# <style>
#
# .stApp {
#     background-color: #f0f2f5;
# }
#
# .user-bubble {
#     background-color: #dcf8c6;
#     color: black;
#     padding: 10px;
#     border-radius: 15px;
#     margin-bottom: 10px;
# }
#
# .bot-bubble {
#     background-color: white;
#     color: black;
#     padding: 10px;
#     border-radius: 15px;
#     margin-bottom: 10px;
# }
#
# </style>

# %%
app_code = '''

import streamlit as st
import ollama

# =====================================
# PAGE CONFIGURATION
# =====================================

st.set_page_config(
    page_title="Multilingual AI Assistant",
    page_icon="🌍",
    layout="centered"
)

# =====================================
# CSS STYLING
# =====================================

st.markdown("""
<style>

.stApp {
    background-color: #f0f2f5;
}

.user-bubble {
    background-color: #dcf8c6;
    color: black;
    padding: 10px;
    border-radius: 15px;
    margin-bottom: 10px;
}

.bot-bubble {
    background-color: white;
    color: black;
    padding: 10px;
    border-radius: 15px;
    margin-bottom: 10px;
}

</style>
""", unsafe_allow_html=True)

# =====================================
# SYSTEM PROMPT
# =====================================

SYSTEM_PROMPT = {
    "role": "system",
    "content": """
You are a highly accurate multilingual AI assistant for Sri Lanka.

Rules:
1. Detect the user's language automatically.
2. If the user writes in Sinhala, reply only in Sinhala.
3. If the user writes in Tamil, reply only in Tamil.
4. If the user writes in English, reply only in English.
5. Never mix languages unless the user mixes them.
6. If unsure, clearly say you do not know.
7. Never hallucinate or invent facts.
8. Keep responses short, accurate, and helpful.
"""
}

# =====================================
# SIDEBAR
# =====================================

with st.sidebar:

    st.success("🟢 Ollama Connected")

    if st.button("🗑 Clear Chat"):
        st.session_state.messages = [SYSTEM_PROMPT]
        st.rerun()

# =====================================
# CHAT MEMORY
# =====================================

if "messages" not in st.session_state:
    st.session_state.messages = [SYSTEM_PROMPT]

# =====================================
# TITLES
# =====================================

st.markdown(
    "<h2 style='text-align:center;'>🌍 Multilingual Offline Chatbot</h2>",
    unsafe_allow_html=True
)

st.markdown(
    "<p style='text-align:center;'>Powered by Ollama + Gemma 3:12b</p>",
    unsafe_allow_html=True
)

# =====================================
# DISPLAY CHAT HISTORY
# =====================================

for message in st.session_state.messages:

    if message["role"] == "user":

        st.markdown(
            f"<div class='user-bubble'>{message['content']}</div>",
            unsafe_allow_html=True
        )

    elif message["role"] == "assistant":

        st.markdown(
            f"<div class='bot-bubble'>{message['content']}</div>",
            unsafe_allow_html=True
        )

# =====================================
# USER INPUT
# =====================================

prompt = st.chat_input("Type your message")

if prompt:

    st.session_state.messages.append({
        "role": "user",
        "content": prompt
    })

    st.rerun()

# =====================================
# GENERATE RESPONSE
# =====================================

if st.session_state.messages[-1]["role"] == "user":

    with st.spinner("Thinking..."):

        try:

            response = ollama.chat(
                model="gemma3:12b",
                messages=st.session_state.messages,
                keep_alive=-1,
                options={
                    "temperature": 0.2,
                    "num_ctx": 4096,
                    "num_predict": 256
                }
            )

            answer = response["message"]["content"]

            st.session_state.messages.append({
                "role": "assistant",
                "content": answer
            })

            st.rerun()

        except Exception as e:

            st.error("Could not connect to Ollama.")

'''

print("Application code generated successfully")
# Out:
# Application code generated successfully

# %%
with open("multilingual_chatbot.py", "w", encoding="utf-8") as f:
    f.write(app_code)

print("Streamlit application file created")
# Out:
# Streamlit application file created

# %%
# !streamlit run multilingual_chatbot.py
# Out:
# ^C
